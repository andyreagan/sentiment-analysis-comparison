# %% [markdown]
# ## Process and analyze NYT sections using sentiment dictionaries
#
# The `analyzeAll.py` script needs to be run for `pickleNYT()`, which should save `"data/nyt/all.dict"`

# %%
import sys
sys.path.append("/Users/andyreagan/tools/python/labMTsimple/")
from labMTsimple.speedy import *
from labMTsimple.storyLab import *

import re
import codecs
from os import listdir,mkdir
from os.path import isfile,isdir
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rc,rcParams
rc("xtick", labelsize=8)
rc("ytick", labelsize=8)
rc("font",**{"family":"serif","serif":["cmr10"]})
# rc("text", usetex=True)
figwidth_onecol = 8.5
figwidth_twocol = figwidth_onecol/2

import numpy as np
from json import loads
import csv
from datetime import datetime,timedelta
import pickle

error_logging = True
sys.path.append("/Users/andyreagan/tools/python/kitchentable")
from dogtoys import *

# %%
def scatter_sections_all(all_happs_arrays,sections,allDicts):
    """Make a scatterplot of NYT sections.

    Needs the happs arrays from each dictionary, and the names of the sections.
    all_happs_arrays = [[],[],...] with each [] the list of happs for each section for that dictionary.
    sections = titles of the sections."""
    
    ranges = np.array([8,8,8,2,2,2])
    centers = np.array([5,5,5,0,0,0])

    import scipy.odr.odrpack as odrpack

    def f(B, x):
        return B[0]*x + B[1]

    linear = odrpack.Model(f)

    # avg_happs_unweighted = my_happs.mean()
    fig = plt.figure(figsize=(12,12))
    # ax = fig.add_axes([.2,.2,.7,.7])
    # going across the bottom
    for i,happs_1 in enumerate(all_happs_arrays[:-1]):
        # going down from the top
        for j,happs_2 in enumerate(all_happs_arrays[i+1:]):
            print(i,j)
            ax = plt.subplot(len(all_happs_arrays)-1,len(all_happs_arrays)-1,i+j*5+1+i*5)
            if i+j*5+1+i*5 > 20:
                plt.xlabel(allDicts[i].title)
            else:
                ax.set_xticklabels([])
            if np.mod(i+j*5+i*5,5) == 0:
                ax.set_ylabel(allDicts[j+i+1].title)
            else:
                ax.set_yticklabels([])

            happs_1_norm = (happs_1-centers[i])/(ranges[i]/2.0)
            happs_2_norm = (happs_2-centers[j+i+1])/(ranges[j+i+1]/2.0)
            plt.scatter(happs_1_norm,happs_2_norm)
            for k,section in enumerate(sections):
                plt.annotate(section,(happs_1_norm[k]+.005,happs_2_norm[k]+.005),fontsize=10)

            mydata = odrpack.RealData(happs_1_norm, happs_2_norm) # sx=set1scoresStd, sy=set2scoresStd)

            myodr = odrpack.ODR(mydata, linear, beta0=[1., 0.])
            myoutput = myodr.run()
            myoutput.pprint()
            # print(myoutput.beta)
            # print(myoutput.sd_beta)

            # ax.scatter(set1scores,set2scores,alpha=0.9,marker="o",c="#F0F0FA",s=12,linewidth=0.0,edgecolor="k")


            x = np.linspace(min(happs_1_norm),max(happs_1_norm),num=10)
            ax.plot(x,myoutput.beta[0]*x+myoutput.beta[1],"r",linewidth=0.75)

            ax.legend(["RMA\n$\\beta$ = {0:.2f}\n$\\alpha$ = {1:.2f}".format(myoutput.beta[0],myoutput.beta[1])],loc="best",fontsize=10,frameon=False,)

    plt.tight_layout(pad=0.5, w_pad=0.0, h_pad=0.0)
    for i,happs_1 in enumerate(all_happs_arrays[:-1]):
        # going down from the top
        for j,happs_2 in enumerate(all_happs_arrays[i+1:]):
            print(i,j)
            ax = plt.subplot(len(all_happs_arrays)-1,len(all_happs_arrays)-1,i+j*5+1+i*5)
            if i+j*5+1+i*5 > 20:
                plt.xlabel(allDicts[i].title,fontsize=15)
            else:
                ax.set_xticklabels([])
            if np.mod(i+j*5+i*5,5) == 0:
                ax.set_ylabel(allDicts[j+i+1].title,fontsize=15)
            else:
                ax.set_yticklabels([])
            # plt.scatter(happs_1,happs_2)
            # for k,section in enumerate(sections):
            #    plt.annotate(section,(happs_1[k],happs_2[k]))
    mysavefig("NYT-scatter-all.png",folder="../figures/nyt")
    mysavefig("NYT-scatter-all.pdf",folder="../figures/nyt")

# %%
def nyt_sorted_barchart(sections,my_senti_dict,my_happs):

    indexer = sorted(range(len(my_happs)),key=lambda x: my_happs[x],reverse=True)

    sections_sorted = [sections[i] for i in indexer]
    my_happs_sorted = [my_happs[i] for i in indexer]
    together_sorted = [(sections[i],my_happs[i]) for i in indexer]

    avg_happs_unweighted = my_happs.mean()

    fig = plt.figure(figsize=(8,12))
    ax = fig.add_axes([.2,.2,.7,.7])
    # ax.bar(np.arange(len(sections)),np.array(my_happs_sorted),orientation="vertical")
    # ax.bar(0,.8,np.array(my_happs_sorted)-avg_happs,bottom=np.arange(len(sections)),orientation="horizontal")
    bar_height = 0.8
    happs_diff = np.array(my_happs_sorted)-avg_happs_unweighted
    rects1 = ax.bar(0,bar_height,happs_diff,bottom=np.arange(len(sections)),orientation="horizontal")
    ax.set_ylim([bar_height-1,len(sections)])
    ax.invert_yaxis()
    ax.set_yticklabels([])
    ax.set_xlabel("Happs diff from unweighted average")
    # ax.set_title("Ranking of NYT Sections by {0}".format(my_senti_dict.title))

    def autolabel(rects):
        # attach some text labels
        for rect in rects:
            height = rect.get_height()
            width = rect.get_width()
            y = rect.get_y()

            x = rect.get_x()
            if happs_diff[y] > 0:
                ax.text(-0.01, y+bar_height/2., "{0:.0f}. {1}".format(y+1,sections_sorted[int(np.floor(y))].replace("_"," ").capitalize()),
                        ha="right", va="center")
            else:
                ax.text(.01, y+bar_height/2., "{0:.0f}. {1}".format(y+1,sections_sorted[int(np.floor(y))].replace("_"," ").capitalize()),
                        ha="left", va="center")

    autolabel(rects1)

    # mysavefig("NYT-sorted-{0}.png".format(my_senti_dict.title),date=False)
    mysavefig("NYT-sorted-{0}.pdf".format(my_senti_dict.title),date=True,folder="../figures/nyt")

# %%
def nyt_happs(sections,my_senti_dict,stopVal = 1.0,make_word_shifts=True,prefix="",use_cache=True):
    """Do everything related to the NYT sections.

    sections: list of section titles
    my_senti_dict: an individual sentiDict subclass
    """
    happs_array = np.zeros(len(sections))
    total_word_vec = np.zeros(len(my_senti_dict.scorelist))
    for i,section in enumerate(sections):
        print(section)
        # check for the csv
        fname = "../data/nyt/sections/NYT_{0}-{1}.csv".format(section,my_senti_dict.title)
        my_word_vec = np.zeros(len(my_senti_dict.scorelist))
        if isfile(fname) and use_cache:
            print("using cache")
            f = open(fname,"r")
            my_word_vec = np.array(list(map(float,f.read().split("\n"))))
            f.close()
        else:
            print("loading dict directly")
            raw_fname = "../data/nyt/sections/NYT_{0}.dict".format(section)
            my_raw_dict = pickle.load( open( raw_fname , "rb" ) )
            my_word_vec = my_senti_dict.wordVecify(my_raw_dict)
            # may not want to either load the word vec,
            # or save a new one, when doing tests of removing stop words
            # should probably just use the stopper for this.
            if use_cache:
                print("saving cache")
                f = open( fname , "w" )
                f.write( "\n".join( list( map( lambda x: "{0:.0f}".format(x) , my_word_vec ) ) ) )
                f.close()
        print(len(my_word_vec))
        print(len(my_senti_dict.stopper(my_word_vec,stopVal=stopVal)))
        my_word_vec = my_senti_dict.stopper(my_word_vec,stopVal=stopVal)
        total_word_vec += my_word_vec

        happs = np.dot(my_word_vec,my_senti_dict.scorelist)/np.sum(my_word_vec)
        print(happs)
        happs_array[i] = happs
   
    avg_happs = np.dot(total_word_vec,my_senti_dict.scorelist)/np.sum(total_word_vec)

    nyt_sorted_barchart(sections,my_senti_dict,happs_array)

    total_word_vec_stopped = my_senti_dict.stopper(total_word_vec)

    if make_word_shifts:
        for i,section in enumerate(sections):
            print(section)
            fname = "../data/nyt/sections/NYT_{0}-{1}.csv".format(section,my_senti_dict.title)
            f = open(fname,"r")
            my_word_vec = np.array(map(int,f.read().split("\n")))
            f.close()
            my_word_vec_stopped = my_senti_dict.stopper(my_word_vec)
            shiftHtml(my_senti_dict.scorelist, my_senti_dict.wordlist, 
                    total_word_vec_stopped, my_word_vec_stopped, 
                    "NYT-shift-{0}-{1}.html".format(my_senti_dict.title,section),
                    # make_png_too=False,open_pdf=False,
                    customTitle=True,
                    title="{0}{1} Wordshift".format(prefix,my_senti_dict.title),
                    ref_name="NYT as a whole",comp_name=section+" section",
                    ref_name_happs="NYT as a whole",comp_name_happs=(section+" section").capitalize())
            # (scoreList, wordList, refFreq, compFreq, outFile)

    return (happs_array,avg_happs)

# %%
def shift_NYT_zipf():
    import scipy.odr.odrpack as odrpack

    def f(B, x):
        return B[0] * (x ** (B[1]))

    power_law = odrpack.Model(f)

    a = pickle.load( open("../data/nyt/sections/NYT_society.dict", "rb") )
    b = pickle.load( open("../data/nyt/all-50k.dict", "rb") )

    words = [word for word in b]
    indexer = sorted(range(len(words)),key=lambda k: b[words[k]], reverse=True)
    sorted_words = [words[i] for i in indexer[:50000]]
    sorted_counts = [b[word] for word in sorted_words]

    society_counts = [a[word] if word in a else 0 for word in sorted_words]

    print(sorted_counts[0])
    mydata = odrpack.RealData(range(1,len(sorted_counts)+1),sorted_counts) # sx=set1scoresStd, sy=set2scoresStd)
    myodr = odrpack.ODR(mydata, power_law, beta0=[sorted_counts[0], -1.])
    myoutput = myodr.run()
    myoutput.pprint()

    # b50k = dict()
    # for word,count in zip(sorted_words,sorted_counts):
    #     b50k[word] = count
    # pickle.dump( b50k , open("data/nyt/all-50k.dict", "wb") )

    # zipf_weights  = [1.0/(i+1.0) for i in range(len(sorted_words))]
    # shiftHtml(zipf_weights,sorted_words,sorted_counts,society_counts,"society-zipf.html")

    # inverse_zipf_weights  = [i+1.0 for i in range(len(sorted_words))]
    # shiftHtml(inverse_zipf_weights,sorted_words,sorted_counts,society_counts,"society-zipf-inv.html")

    # inverse_counts = [1.0/count for count in sorted_counts]
    # shiftHtml(inverse_counts,sorted_words,sorted_counts,society_counts,"society-counts-inv.html")

    inverse_zipf_weights_fitted  = [1.0/(myoutput.beta[0]*( (i+1) ** myoutput.beta[1] )) for i in range(len(sorted_words))]
    print(inverse_zipf_weights_fitted[:10])
    shiftHtml(inverse_zipf_weights_fitted,sorted_words,sorted_counts,society_counts,"society-zipf-inv-fit.html")

# %%
def marriage_words():
    a = pickle.load( open("../data/nyt/sections/NYT_society.dict", "rb") )
    matches = []
    for word in a:
        if word[0:3] == "mar":
            matches.append((word,a[word]))
    indexer = sorted(range(len(matches)),key=lambda k: matches[k][1],reverse=True)
    sorted_matches = [matches[i] for i in indexer]
    for i in range(6):
        print(sorted_matches[i][0]+" ")
        print("("+str(sorted_matches[i][1])+"), ")

# %%
shift_NYT_zipf()
# Out:
# 62300834
# Beta: [  7.52493931e+08  -1.26390595e+00]
# Beta Std Error: [  7.03569863e+06   9.93450930e-04]
# Beta Covariance: [[  3.50854957e+08  -4.94284617e-02]
#  [ -4.94284617e-02   6.99529448e-12]]
# Residual Variance: 141086.94824798944
# Inverse Condition #: 0.0005884049705750796
# Reason(s) for Halting:
#   Iteration limit reached
# [1.3289143726302138e-09, 3.1913218057758828e-09, 5.3276218193498407e-09, 7.6638006765350923e-09, 1.0160833678091452e-08, 1.2794018964041694e-08, 1.5546099233113831e-08, 1.8404236358539282e-08, 2.1358452308582689e-08, 2.4400736984713365e-08]
# wrote shift to society-zipf-inv-fit.html

# %% [markdown]
# ### Now do everything related the NYT classification.
#
# Calls nyt_happs()
# Optionally scatter_sections_all() next

# %%
sections = ["arts","books","classified","cultural","editorial","education","financial","foreign","home","leisure","living","magazine","metropolitan","movies","national","regional","science","society","sports","style","television","travel","week-in-review","weekend",]

stopVal = 0.0
allDicts = (LabMT(stopVal=stopVal),
            ANEW(stopVal=stopVal),
            WK(stopVal=stopVal),
            MPQA(stopVal=stopVal),
            LIWC(stopVal=stopVal),
            Liu(stopVal=stopVal))


all_stopVals = [1.0,1.0,1.0,0.5,0.5,0.5]
all_happs_arrays = [[] for i in range(len(allDicts))]
for k,my_dict in enumerate(allDicts):
# all_stopVals = [0.5,]
# for i,my_dict in enumerate([allDicts[4]]):
    print("#"*80)
    print(my_dict.title)
    print("#"*80)
    my_happs_array,avg_happs = nyt_happs(sections,
                                         my_dict,
                                         stopVal=all_stopVals[k],
                                         make_word_shifts=False,
                                         prefix=letters[k]+": ",
                                         use_cache=True)
    all_happs_arrays[k] = my_happs_array
# Out:
# loading LabMT with stopVal=0.0, for 10222 words
# loading ANEW with stopVal=0.0, for 1034 words
# loading WK with stopVal=0.0, for 13915 words
# loading MPQA with stopVal=0.0, for 7192 words
# loading data/LIWC/LIWC2007_English100131_words.dic
# loading LIWC with stopVal=0.0, for 4483 words
# loading Liu with stopVal=0.0, for 6782 words
# ################################################################################
# LabMT
# ################################################################################
# arts
# using cache
# 10222
# 10222
# 6.12564951135
# books
# using cache
# 10222
# 10222
# 5.99048066404
# classified
# using cache
# 10222
# 10222
# 6.04981622109
# cultural
# using cache
# 10222
# 10222
# 6.14259982978
# editorial
# using cache
# 10222
# 10222
# 5.73679623558
# education
# using cache
# 10222
# 10222
# 6.11494577514
# financial
# using cache
# 10222
# 10222
# 5.96282664347
# foreign
# using cache
# 10222
# 10222
# 5.60582531189
# home
# using cache
# 10222
# 10222
# 6.14656546381
# leisure
# using cache
# 10222
# 10222
# 6.29396837745
# living
# using cache
# 10222
# 10222
# 6.1716031366
# magazine
# using cache
# 10222
# 10222
# 5.98384993178
# metropolitan
# using cache
# 10222
# 10222
# 5.73046816405
# movies
# using cache
# 10222
# 10222
# 6.21273550976
# national
# using cache
# 10222
# 10222
# 5.71054162147
# regional
# using cache
# 10222
# 10222
# 6.10630842424
# science
# using cache
# 10222
# 10222
# 5.86087402341
# society
# using cache
# 10222
# 10222
# 6.41653837396
# sports
# using cache
# 10222
# 10222
# 5.93152943359
# style
# using cache
# 10222
# 10222
# 6.13900099218
# television
# using cache
# 10222
# 10222
# 6.01316363636
# travel
# using cache
# 10222
# 10222
# 6.01462765957
# week-in-review
# using cache
# 10222
# 10222
# 5.73515842886
# weekend
# using cache
# 10222
# 10222
# 6.22251794388
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ################################################################################
# ANEW
# ################################################################################
# arts
# using cache
# 1034
# 1034
# 6.53601154251
# books
# using cache
# 1034
# 1034
# 6.2792096953
# classified
# using cache
# 1034
# 1034
# 6.63253080051
# cultural
# using cache
# 1034
# 1034
# 6.53200743029
# editorial
# using cache
# 1034
# 1034
# 5.99587582903
# education
# using cache
# 1034
# 1034
# 6.65635257572
# financial
# using cache
# 1034
# 1034
# 6.30388936166
# foreign
# using cache
# 1034
# 1034
# 5.95987175872
# home
# using cache
# 1034
# 1034
# 6.62881446924
# leisure
# using cache
# 1034
# 1034
# 6.68731569963
# living
# using cache
# 1034
# 1034
# 6.48824632435
# magazine
# using cache
# 1034
# 1034
# 6.37062760029
# metropolitan
# using cache
# 1034
# 1034
# 6.08232131642
# movies
# using cache
# 1034
# 1034
# 6.59324733257
# national
# using cache
# 1034
# 1034
# 6.07213285088
# regional
# using cache
# 1034
# 1034
# 6.53923540472
# science
# using cache
# 1034
# 1034
# 6.01275290061
# society
# using cache
# 1034
# 1034
# 6.97623075696
# sports
# using cache
# 1034
# 1034
# 6.46142144784
# style
# using cache
# 1034
# 1034
# 6.6464638424
# television
# using cache
# 1034
# 1034
# 6.38956521739
# travel
# using cache
# 1034
# 1034
# 6.38
# week-in-review
# using cache
# 1034
# 1034
# 6.04173252011
# weekend
# using cache
# 1034
# 1034
# 6.61659682775
# ################################################################################
# WK
# ################################################################################
# arts
# using cache
# 13915
# 13915
# 6.2481877406
# books
# using cache
# 13915
# 13915
# 6.05137051061
# classified
# using cache
# 13915
# 13915
# 6.2597090511
# cultural
# using cache
# 13915
# 13915
# 6.26016786073
# editorial
# using cache
# 13915
# 13915
# 5.76067063119
# education
# using cache
# 13915
# 13915
# 6.17182845623
# financial
# using cache
# 13915
# 13915
# 5.99274963775
# foreign
# using cache
# 13915
# 13915
# 5.66235882319
# home
# using cache
# 13915
# 13915
# 6.30249139158
# leisure
# using cache
# 13915
# 13915
# 6.38695609733
# living
# using cache
# 13915
# 13915
# 6.29792687667
# magazine
# using cache
# 13915
# 13915
# 6.09723510435
# metropolitan
# using cache
# 13915
# 13915
# 5.82857688547
# movies
# using cache
# 13915
# 13915
# 6.26407154303
# national
# using cache
# 13915
# 13915
# 5.71098295628
# regional
# using cache
# 13915
# 13915
# 6.23507425064
# science
# using cache
# 13915
# 13915
# 5.90798268108
# society
# using cache
# 13915
# 13915
# 6.43327838045
# sports
# using cache
# 13915
# 13915
# 6.16130512792
# style
# using cache
# 13915
# 13915
# 6.28989175235
# television
# using cache
# 13915
# 13915
# 6.07464114833
# travel
# using cache
# 13915
# 13915
# 6.2728340081
# week-in-review
# using cache
# 13915
# 13915
# 5.77126418722
# weekend
# using cache
# 13915
# 13915
# 6.3104742912
# ################################################################################
# MPQA
# ################################################################################
# arts
# using cache
# 7192
# 7192
# 0.136592054881
# books
# using cache
# 7192
# 7192
# 0.051679116417
# classified
# using cache
# 7192
# 7192
# 0.161922110579
# cultural
# using cache
# 7192
# 7192
# 0.136434353669
# editorial
# using cache
# 7192
# 7192
# 0.0519953764108
# education
# using cache
# 7192
# 7192
# 0.167745415318
# financial
# using cache
# 7192
# 7192
# 0.0528457372186
# foreign
# using cache
# 7192
# 7192
# -0.0451304126282
# home
# using cache
# 7192
# 7192
# 0.164985446537
# leisure
# using cache
# 7192
# 7192
# 0.161759725094
# living
# using cache
# 7192
# 7192
# 0.156010742502
# magazine
# using cache
# 7192
# 7192
# 0.086252746687
# metropolitan
# using cache
# 7192
# 7192
# 0.0192794887014
# movies
# using cache
# 7192
# 7192
# 0.133601694222
# national
# using cache
# 7192
# 7192
# 0.0320209513992
# regional
# using cache
# 7192
# 7192
# 0.141009348633
# science
# using cache
# 7192
# 7192
# 0.00652654468094
# society
# using cache
# 7192
# 7192
# 0.0406506587408
# sports
# using cache
# 7192
# 7192
# 0.0951560166407
# style
# using cache
# 7192
# 7192
# 0.173445085485
# television
# using cache
# 7192
# 7192
# -0.0869565217391
# travel
# using cache
# 7192
# 7192
# 0.2
# week-in-review
# using cache
# 7192
# 7192
# 0.012567270978
# weekend
# using cache
# 7192
# 7192
# 0.129136636229
# ################################################################################
# LIWC
# ################################################################################
# arts
# using cache
# 4483
# 4483
# 0.342680694256
# books
# using cache
# 4483
# 4483
# 0.181603625249
# classified
# using cache
# 4483
# 4483
# 0.316448336237
# cultural
# using cache
# 4483
# 4483
# 0.35581274524
# editorial
# using cache
# 4483
# 4483
# 0.0955273151859
# education
# using cache
# 4483
# 4483
# 0.243058938139
# financial
# using cache
# 4483
# 4483
# 0.314122119952
# foreign
# using cache
# 4483
# 4483
# -0.0151876937671
# home
# using cache
# 4483
# 4483
# 0.32363991883
# leisure
# using cache
# 4483
# 4483
# 0.475470698832
# living
# using cache
# 4483
# 4483
# 0.351721814463
# magazine
# using cache
# 4483
# 4483
# 0.210254866796
# metropolitan
# using cache
# 4483
# 4483
# 0.0737029918541
# movies
# using cache
# 4483
# 4483
# 0.372506703957
# national
# using cache
# 4483
# 4483
# 0.0897943696745
# regional
# using cache
# 4483
# 4483
# 0.346241306782
# science
# using cache
# 4483
# 4483
# 0.0826849863006
# society
# using cache
# 4483
# 4483
# 0.518608688057
# sports
# using cache
# 4483
# 4483
# 0.262830902266
# style
# using cache
# 4483
# 4483
# 0.396320663349
# television
# using cache
# 4483
# 4483
# 0.25
# travel
# using cache
# 4483
# 4483
# 0.137931034483
# week-in-review
# using cache
# 4483
# 4483
# 0.064235428819
# weekend
# using cache
# 4483
# 4483
# 0.405987356609
# ################################################################################
# Liu
# ################################################################################
# arts
# using cache
# 6782
# 6782
# 0.165073234438
# books
# using cache
# 6782
# 6782
# 0.0181729938643
# classified
# using cache
# 6782
# 6782
# 0.199715387426
# cultural
# using cache
# 6782
# 6782
# 0.17820496873
# editorial
# using cache
# 6782
# 6782
# -0.0533859707812
# education
# using cache
# 6782
# 6782
# 0.147374159549
# financial
# using cache
# 6782
# 6782
# 0.0207603616623
# foreign
# using cache
# 6782
# 6782
# -0.16217715872
# home
# using cache
# 6782
# 6782
# 0.201852912415
# leisure
# using cache
# 6782
# 6782
# 0.331532300906
# living
# using cache
# 6782
# 6782
# 0.226650197062
# magazine
# using cache
# 6782
# 6782
# 0.0688016126923
# metropolitan
# using cache
# 6782
# 6782
# -0.112347916476
# movies
# using cache
# 6782
# 6782
# 0.165492534391
# national
# using cache
# 6782
# 6782
# -0.0994679291468
# regional
# using cache
# 6782
# 6782
# 0.178362305982
# science
# using cache
# 6782
# 6782
# -0.0617085214571
# society
# using cache
# 6782
# 6782
# 0.16833225638
# sports
# using cache
# 6782
# 6782
# 0.189378788168
# style
# using cache
# 6782
# 6782
# 0.224927391975
# television
# using cache
# 6782
# 6782
# 0.0512820512821
# travel
# using cache
# 6782
# 6782
# 0.239436619718
# week-in-review
# using cache
# 6782
# 6782
# -0.0834880913691
# weekend
# using cache
# 6782
# 6782
# 0.217925562838

# %%
scatter_sections_all(all_happs_arrays,sections,allDicts)
# Out:
# 0 0
# Beta: [ 1.33870926  0.01243049]
# Beta Std Error: [ 0.0962385   0.02492588]
# Beta Covariance: [[ 48.8091676  -12.41500517]
#  [-12.41500517   3.27419572]]
# Residual Variance: 0.00018975631902637014
# Inverse Condition #: 0.055400630688952755
# Reason(s) for Halting:
#   Sum of squares convergence
# 0 1
# Beta: [ 1.12330979 -0.00705613]
# Beta Std Error: [ 0.07116956  0.01843916]
# Beta Covariance: [[ 38.80764722  -9.87103636]
#  [ -9.87103636   2.60501982]]
# Residual Variance: 0.0001305182342102551
# Inverse Condition #: 0.055915041308518806
# Reason(s) for Halting:
#   Sum of squares convergence
# 0 2
# Beta: [ 1.89819262 -0.39200721]
# Beta Std Error: [ 0.43413747  0.11166834]
# Beta Covariance: [[ 131.06039391  -33.33629097]
#  [ -33.33629097    8.67115756]]
# Residual Variance: 0.0014380800762910442
# Inverse Condition #: 0.043432521587001414
# Reason(s) for Halting:
#   Sum of squares convergence
# 0 3
# Beta: [ 2.9263104 -0.4861646]
# Beta Std Error: [ 0.21736794  0.05625254]
# Beta Covariance: [[ 175.23739544  -44.57307579]
#  [ -44.57307579   11.73599972]]
# Residual Variance: 0.000269627498289015
# Inverse Condition #: 0.05412187932138172
# Reason(s) for Halting:
#   Sum of squares convergence
# 0 4
# Beta: [ 2.97527024 -0.65592201]
# Beta Std Error: [ 0.34788008  0.08984863]
# Beta Covariance: [[ 204.46640949  -52.00771642]
#  [ -52.00771642   13.63910102]]
# Residual Variance: 0.0005918847596656473
# Inverse Condition #: 0.050873402043270365
# Reason(s) for Halting:
#   Sum of squares convergence
# 1 0
# Beta: [ 0.83925769 -0.01754251]
# Beta Std Error: [ 0.06312246  0.02265493]
# Beta Covariance: [[ 16.73366361  -5.9060244 ]
#  [ -5.9060244    2.15550314]]
# Residual Variance: 0.000238109566867733
# Inverse Condition #: 0.04120746960662501
# Reason(s) for Halting:
#   Sum of squares convergence
# 1 1
# Beta: [ 1.22044623 -0.33993327]
# Beta Std Error: [ 0.25292796  0.09042195]
# Beta Covariance: [[ 32.02882204 -11.30432353]
#  [-11.30432353   4.09350174]]
# Residual Variance: 0.001997343318656636
# Inverse Condition #: 0.0360652362372173
# Reason(s) for Halting:
#   Sum of squares convergence
# 1 2
# Beta: [ 2.23279089 -0.52987961]
# Beta Std Error: [ 0.19228763  0.06891882]
# Beta Covariance: [[ 64.05641214 -22.60821285]
#  [-22.60821285   8.22878282]]
# Residual Variance: 0.0005772183153609375
# Inverse Condition #: 0.03949771848650819
# Reason(s) for Halting:
#   Sum of squares convergence
# 1 3
# Beta: [ 2.21457931 -0.68075605]
# Beta Std Error: [ 0.25565764  0.09152865]
# Beta Covariance: [[ 68.24704052 -24.08726238]
#  [-24.08726238   8.74742706]]
# Residual Variance: 0.0009577093835371809
# Inverse Condition #: 0.038026646885873136
# Reason(s) for Halting:
#   Sum of squares convergence
# 2 0
# Beta: [ 1.48941337 -0.32423658]
# Beta Std Error: [ 0.26319949  0.07444659]
# Beta Covariance: [[ 57.05885983 -15.90041948]
#  [-15.90041948   4.5650197 ]]
# Residual Variance: 0.0012140791731887945
# Inverse Condition #: 0.046865765817982255
# Reason(s) for Halting:
#   Sum of squares convergence
# 2 1
# Beta: [ 2.71312674 -0.49789224]
# Beta Std Error: [ 0.27934235  0.07915561]
# Beta Covariance: [[ 131.96241123  -36.77356626]
#  [ -36.77356626   10.59595592]]
# Residual Variance: 0.0005913210125963786
# Inverse Condition #: 0.049648011783893706
# Reason(s) for Halting:
#   Sum of squares convergence
# 2 2
# Beta: [ 2.47284797 -0.58823855]
# Beta Std Error: [ 0.16372978  0.04647307]
# Beta Covariance: [[ 101.87928671  -28.3903922 ]
#  [ -28.3903922     8.20792197]]
# Residual Variance: 0.00026312945091927183
# Inverse Condition #: 0.05209464190818675
# Reason(s) for Halting:
#   Sum of squares convergence
# 3 0
# Beta: [ 2.79925998  0.00395533]
# Beta Std Error: [ 0.76165764  0.07872944]
# Beta Covariance: [[ 151.04653262  -13.71708876]
#  [ -13.71708876    1.61385871]]
# Residual Variance: 0.0038406864250453434
# Inverse Condition #: 0.2239508550911326
# Reason(s) for Halting:
#   Sum of squares convergence
# 3 1
# Beta: [ 2.00921663 -0.08160197]
# Beta Std Error: [ 0.28310512  0.03176401]
# Beta Covariance: [[ 48.34220685  -4.39013592]
#  [ -4.39013592   0.60855759]]
# Residual Variance: 0.0016579405935267131
# Inverse Condition #: 0.29157525753280544
# Reason(s) for Halting:
#   Sum of squares convergence
# 4 0
# Beta: [ 0.94792853 -0.14386096]
# Beta Std Error: [ 0.12032011  0.03501993]
# Beta Covariance: [[ 4.37931208 -1.13059205]
#  [-1.13059205  0.37098811]]
# Residual Variance: 0.0033057543072730344
# Inverse Condition #: 0.1343956099874221
# Reason(s) for Halting:
#   Sum of squares convergence
# 0 0
# 0 1
# 0 2
# 0 3
# 0 4
# 1 0
# 1 1
# 1 2
# 1 3
# 2 0
# 2 1
# 2 2
# 3 0
# 3 1
# 4 0

# %%
# fix Liu
for word in ["vice","miss"]:
    if word in allDicts[5].data:
        print("removing "+word)
        allDicts[5].scorelist[allDicts[5].data[word][0]] = 0.0
    else:
        print(word+" not in Liu")
# Out:
# removing vice
# removing miss

# %%
for word in ["mar*","retire*","vice","bar*","miss*"]:
    if word in allDicts[3].data:
        print("removing "+word)
        allDicts[3].scorelist[allDicts[3].data[word][0]] = 0.0
    else:
        print(word+" not in MPQA")
# Out:
# removing mar*
# removing retire*
# removing vice
# removing bar*
# removing miss*

# %%
for k,my_dict in enumerate(allDicts):
# all_stopVals = [0.5,]
# for i,my_dict in enumerate([allDicts[4]]):
    print("#"*80)
    print(my_dict.title)
    print("#"*80)
    my_happs_array,avg_happs = nyt_happs(sections,
                                         my_dict,
                                         stopVal=all_stopVals[k],
                                         make_word_shifts=False,
                                         prefix=letters[k]+": ",
                                         use_cache=False)
    all_happs_arrays[k] = my_happs_array
# Out:
# ################################################################################
# LabMT
# ################################################################################
# arts
# loading dict directly
# 10222
# 10222
# 6.12564951135
# books
# loading dict directly
# 10222
# 10222
# 5.99048066404
# classified
# loading dict directly
# 10222
# 10222
# 6.04981622109
# cultural
# loading dict directly
# 10222
# 10222
# 6.14259982978
# editorial
# loading dict directly
# 10222
# 10222
# 5.73679623558
# education
# loading dict directly
# 10222
# 10222
# 6.11494577514
# financial
# loading dict directly
# 10222
# 10222
# 5.96282664347
# foreign
# loading dict directly
# 10222
# 10222
# 5.60582531189
# home
# loading dict directly
# 10222
# 10222
# 6.14656546381
# leisure
# loading dict directly
# 10222
# 10222
# 6.29396837745
# living
# loading dict directly
# 10222
# 10222
# 6.1716031366
# magazine
# loading dict directly
# 10222
# 10222
# 5.98384993178
# metropolitan
# loading dict directly
# 10222
# 10222
# 5.73046816405
# movies
# loading dict directly
# 10222
# 10222
# 6.21273550976
# national
# loading dict directly
# 10222
# 10222
# 5.71054162147
# regional
# loading dict directly
# 10222
# 10222
# 6.10630842424
# science
# loading dict directly
# 10222
# 10222
# 5.86087402341
# society
# loading dict directly
# 10222
# 10222
# 6.41653837396
# sports
# loading dict directly
# 10222
# 10222
# 5.93152943359
# style
# loading dict directly
# 10222
# 10222
# 6.13900099218
# television
# loading dict directly
# 10222
# 10222
# 6.01316363636
# travel
# loading dict directly
# 10222
# 10222
# 6.01462765957
# week-in-review
# loading dict directly
# 10222
# 10222
# 5.73515842886
# weekend
# loading dict directly
# 10222
# 10222
# 6.22251794388
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:32: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ################################################################################
# ANEW
# ################################################################################
# arts
# loading dict directly
# 1034
# 1034
# 6.53601154251
# books
# loading dict directly
# 1034
# 1034
# 6.2792096953
# classified
# loading dict directly
# 1034
# 1034
# 6.63253080051
# cultural
# loading dict directly
# 1034
# 1034
# 6.53200743029
# editorial
# loading dict directly
# 1034
# 1034
# 5.99587582903
# education
# loading dict directly
# 1034
# 1034
# 6.65635257572
# financial
# loading dict directly
# 1034
# 1034
# 6.30388936166
# foreign
# loading dict directly
# 1034
# 1034
# 5.95987175872
# home
# loading dict directly
# 1034
# 1034
# 6.62881446924
# leisure
# loading dict directly
# 1034
# 1034
# 6.68731569963
# living
# loading dict directly
# 1034
# 1034
# 6.48824632435
# magazine
# loading dict directly
# 1034
# 1034
# 6.37062760029
# metropolitan
# loading dict directly
# 1034
# 1034
# 6.08232131642
# movies
# loading dict directly
# 1034
# 1034
# 6.59324733257
# national
# loading dict directly
# 1034
# 1034
# 6.07213285088
# regional
# loading dict directly
# 1034
# 1034
# 6.53923540472
# science
# loading dict directly
# 1034
# 1034
# 6.01275290061
# society
# loading dict directly
# 1034
# 1034
# 6.97623075696
# sports
# loading dict directly
# 1034
# 1034
# 6.46142144784
# style
# loading dict directly
# 1034
# 1034
# 6.6464638424
# television
# loading dict directly
# 1034
# 1034
# 6.38956521739
# travel
# loading dict directly
# 1034
# 1034
# 6.38
# week-in-review
# loading dict directly
# 1034
# 1034
# 6.04173252011
# weekend
# loading dict directly
# 1034
# 1034
# 6.61659682775
# ################################################################################
# WK
# ################################################################################
# arts
# loading dict directly
# 13915
# 13915
# 6.2481877406
# books
# loading dict directly
# 13915
# 13915
# 6.05137051061
# classified
# loading dict directly
# 13915
# 13915
# 6.2597090511
# cultural
# loading dict directly
# 13915
# 13915
# 6.26016786073
# editorial
# loading dict directly
# 13915
# 13915
# 5.76067063119
# education
# loading dict directly
# 13915
# 13915
# 6.17182845623
# financial
# loading dict directly
# 13915
# 13915
# 5.99274963775
# foreign
# loading dict directly
# 13915
# 13915
# 5.66235882319
# home
# loading dict directly
# 13915
# 13915
# 6.30249139158
# leisure
# loading dict directly
# 13915
# 13915
# 6.38695609733
# living
# loading dict directly
# 13915
# 13915
# 6.29792687667
# magazine
# loading dict directly
# 13915
# 13915
# 6.09723510435
# metropolitan
# loading dict directly
# 13915
# 13915
# 5.82857688547
# movies
# loading dict directly
# 13915
# 13915
# 6.26407154303
# national
# loading dict directly
# 13915
# 13915
# 5.71098295628
# regional
# loading dict directly
# 13915
# 13915
# 6.23507425064
# science
# loading dict directly
# 13915
# 13915
# 5.90798268108
# society
# loading dict directly
# 13915
# 13915
# 6.43327838045
# sports
# loading dict directly
# 13915
# 13915
# 6.16130512792
# style
# loading dict directly
# 13915
# 13915
# 6.28989175235
# television
# loading dict directly
# 13915
# 13915
# 6.07464114833
# travel
# loading dict directly
# 13915
# 13915
# 6.2728340081
# week-in-review
# loading dict directly
# 13915
# 13915
# 5.77126418722
# weekend
# loading dict directly
# 13915
# 13915
# 6.3104742912
# ################################################################################
# MPQA
# ################################################################################
# arts
# loading dict directly
# 7192
# 7192
# 0.137413618018
# books
# loading dict directly
# 7192
# 7192
# 0.0521538568153
# classified
# loading dict directly
# 7192
# 7192
# 0.166755557778
# cultural
# loading dict directly
# 7192
# 7192
# 0.13742200541
# editorial
# loading dict directly
# 7192
# 7192
# 0.0532574165892
# education
# loading dict directly
# 7192
# 7192
# 0.169743358847
# financial
# loading dict directly
# 7192
# 7192
# 0.0591026501327
# foreign
# loading dict directly
# 7192
# 7192
# -0.0441064968806
# home
# loading dict directly
# 7192
# 7192
# 0.166475838008
# leisure
# loading dict directly
# 7192
# 7192
# 0.162267647331
# living
# loading dict directly
# 7192
# 7192
# 0.157231592811
# magazine
# loading dict directly
# 7192
# 7192
# 0.0871994264378
# metropolitan
# loading dict directly
# 7192
# 7192
# 0.0209592689823
# movies
# loading dict directly
# 7192
# 7192
# 0.134082842675
# national
# loading dict directly
# 7192
# 7192
# 0.0352795073756
# regional
# loading dict directly
# 7192
# 7192
# 0.142222285279
# science
# loading dict directly
# 7192
# 7192
# 0.00725523967726
# society
# loading dict directly
# 7192
# 7192
# 0.0692933266599
# sports
# loading dict directly
# 7192
# 7192
# 0.0964946315296
# style
# loading dict directly
# 7192
# 7192
# 0.176043451588
# television
# loading dict directly
# 7192
# 7192
# -0.0869565217391
# travel
# loading dict directly
# 7192
# 7192
# 0.2
# week-in-review
# loading dict directly
# 7192
# 7192
# 0.014096263641
# weekend
# loading dict directly
# 7192
# 7192
# 0.129649740263
# ################################################################################
# LIWC
# ################################################################################
# arts
# loading dict directly
# 4483
# 4483
# 0.342680694256
# books
# loading dict directly
# 4483
# 4483
# 0.181603625249
# classified
# loading dict directly
# 4483
# 4483
# 0.316448336237
# cultural
# loading dict directly
# 4483
# 4483
# 0.35581274524
# editorial
# loading dict directly
# 4483
# 4483
# 0.0955273151859
# education
# loading dict directly
# 4483
# 4483
# 0.243058938139
# financial
# loading dict directly
# 4483
# 4483
# 0.314122119952
# foreign
# loading dict directly
# 4483
# 4483
# -0.0151876937671
# home
# loading dict directly
# 4483
# 4483
# 0.32363991883
# leisure
# loading dict directly
# 4483
# 4483
# 0.475470698832
# living
# loading dict directly
# 4483
# 4483
# 0.351721814463
# magazine
# loading dict directly
# 4483
# 4483
# 0.210254866796
# metropolitan
# loading dict directly
# 4483
# 4483
# 0.0737029918541
# movies
# loading dict directly
# 4483
# 4483
# 0.372506703957
# national
# loading dict directly
# 4483
# 4483
# 0.0897943696745
# regional
# loading dict directly
# 4483
# 4483
# 0.346241306782
# science
# loading dict directly
# 4483
# 4483
# 0.0826849863006
# society
# loading dict directly
# 4483
# 4483
# 0.518608688057
# sports
# loading dict directly
# 4483
# 4483
# 0.262830902266
# style
# loading dict directly
# 4483
# 4483
# 0.396320663349
# television
# loading dict directly
# 4483
# 4483
# 0.25
# travel
# loading dict directly
# 4483
# 4483
# 0.137931034483
# week-in-review
# loading dict directly
# 4483
# 4483
# 0.064235428819
# weekend
# loading dict directly
# 4483
# 4483
# 0.405987356609
# ################################################################################
# Liu
# ################################################################################
# arts
# loading dict directly
# 6782
# 6782
# 0.169758517339
# books
# loading dict directly
# 6782
# 6782
# 0.0204967452804
# classified
# loading dict directly
# 6782
# 6782
# 0.213360483278
# cultural
# loading dict directly
# 6782
# 6782
# 0.191470567862
# editorial
# loading dict directly
# 6782
# 6782
# -0.0502838752654
# education
# loading dict directly
# 6782
# 6782
# 0.157045995968
# financial
# loading dict directly
# 6782
# 6782
# 0.0343260216366
# foreign
# loading dict directly
# 6782
# 6782
# -0.159215297781
# home
# loading dict directly
# 6782
# 6782
# 0.209865987913
# leisure
# loading dict directly
# 6782
# 6782
# 0.334547598989
# living
# loading dict directly
# 6782
# 6782
# 0.233013219496
# magazine
# loading dict directly
# 6782
# 6782
# 0.0721715458091
# metropolitan
# loading dict directly
# 6782
# 6782
# -0.106717315001
# movies
# loading dict directly
# 6782
# 6782
# 0.168283208795
# national
# loading dict directly
# 6782
# 6782
# -0.0923458108207
# regional
# loading dict directly
# 6782
# 6782
# 0.183977518348
# science
# loading dict directly
# 6782
# 6782
# -0.0596160045692
# society
# loading dict directly
# 6782
# 6782
# 0.297721932179
# sports
# loading dict directly
# 6782
# 6782
# 0.196592716297
# style
# loading dict directly
# 6782
# 6782
# 0.235602847835
# television
# loading dict directly
# 6782
# 6782
# 0.0512820512821
# travel
# loading dict directly
# 6782
# 6782
# 0.239436619718
# week-in-review
# loading dict directly
# 6782
# 6782
# -0.0796917504073
# weekend
# loading dict directly
# 6782
# 6782
# 0.227800939335
